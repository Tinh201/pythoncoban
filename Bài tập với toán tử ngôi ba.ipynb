# %%
num_check = 46

# USING TERNARY OPERATOR
msg = "Even" if num_check %2 == 0 else "Odd"
print(msg)

# USING USUAL IF-ELSE
msg = ""
if(num_check%2  == 0):
msg = "Even"
else:
msg = "Odd"
print(msg)ß
# Out:
#   File "C:\Users\Admin\AppData\Local\Temp/ipykernel_11760/4061130723.py", line 10
#     msg = "Even"
#     ^
# IndentationError: expected an indented block
